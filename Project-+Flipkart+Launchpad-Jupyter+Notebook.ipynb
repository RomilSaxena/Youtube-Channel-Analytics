# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
a="22-10-2015 22:10:44"

# %%
a
# Out:
# '22-10-2015 22:10:44'

# %%
a[0:10]
# Out:
# '22-10-2015'

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# ### Subtask 1.1: Loading data
#
# * 1.1. Import the data set into the Jupyter Notebook (0.5 marks)

# %%
videos= pd.read_csv("YouTube+Video+Statistics+1.csv") #Loading the Dataset

# %%
videos.views.mean()
# Out:
# 1037450.0646789132

# %%
videos.describe().round()
# Out:
#        category_id       views      likes  dislikes  comment_count
# count      32499.0     32499.0    32499.0   32499.0        32499.0
# mean          22.0   1037450.0    27914.0    1512.0         2693.0
# std            6.0   3011706.0    95690.0    5269.0        12340.0
# min            1.0      4287.0        0.0       0.0            0.0
# 25%           23.0    121592.0      888.0     113.0           87.0
# 50%           24.0    299761.0     3211.0     340.0          347.0
# 75%           24.0    798744.0    14688.0    1052.0         1353.0
# max           43.0  89930713.0  2606663.0  182589.0       382685.0

# %% [markdown]
# ### Subtask 1.2: Inspect the dataframe
#
# * 1.2. Inspect the data frame's columns, shape and variable types (2 marks)

# %%
videos['week_year'] = channel1DF.apply(lambda row: row.dislikes / row.likes, axis=1)

# %%
# Write your code for inspection here

videos.info() #Getting information about the dataset we can see the range, columns, columnname, type
videos.shape #Shape of the dataset(Rows,Columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32499 entries, 0 to 32498
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           32499 non-null  object
#  1   trending_date      32499 non-null  object
#  2   title              32499 non-null  object
#  3   channel_title      32499 non-null  object
#  4   category_id        32499 non-null  int64
#  5   tags               32499 non-null  object
#  6   views              32499 non-null  int64
#  7   likes              32499 non-null  int64
#  8   dislikes           32499 non-null  int64
#  9   comment_count      32499 non-null  int64
#  10  comments_disabled  32499 non-null  bool
#  11  ratings_disabled   32499 non-null  bool
#  12  description        31983 non-null  object
# dtypes: bool(2), int64(5), object(6)
# memory usage: 2.8+ MB
# (32499, 13)

# %% [markdown]
# ### Subtask 1.3: Display the summary statistics
# * 1.3. Display the summary statistics for the data set (0.5 marks)

# %%
# write your code for inspection here

videos.describe() #Statistics for all the numeric columns in the dataset
# Out:
#         category_id         views         likes       dislikes  comment_count
# count  32499.000000  3.249900e+04  3.249900e+04   32499.000000   32499.000000
# mean      21.564387  1.037450e+06  2.791356e+04    1511.579926    2692.979138
# std        6.342915  3.011706e+06  9.569039e+04    5269.151723   12340.232792
# min        1.000000  4.287000e+03  0.000000e+00       0.000000       0.000000
# 25%       23.000000  1.215920e+05  8.880000e+02     113.000000      87.000000
# 50%       24.000000  2.997610e+05  3.211000e+03     340.000000     347.000000
# 75%       24.000000  7.987440e+05  1.468850e+04    1052.500000    1353.000000
# max       43.000000  8.993071e+07  2.606663e+06  182589.000000  382685.000000

# %% [markdown]
# ### Subtask 1.4: Draw insights from the statistics
# * 1.4.1. Find the average number of views for all the videos in the data set (1 mark)
# * 1.4.2. Find the details of the video with the highest number of views (1 mark)

# %%
videos[["views"]].mean()

#Mean function gives the mean of all the rows of 'views' column
# Out:
# views    1.037450e+06
# dtype: float64

# %%
videos.loc[videos['views'].idxmax()]

# idxmax() gives the row with maximum number in the column 'views'
# Out:
# video_id                                                   6ZfuNTqbHE8
# trending_date                                                 17.07.12
# title                Marvel Studios' Avengers: Infinity War Officia...
# channel_title                                     Marvel Entertainment
# category_id                                                         24
# tags                 marvel|"comics"|"comic books"|"nerdy"|"geeky"|...
# views                                                         89930713
# likes                                                          2606663
# dislikes                                                         53011
# comment_count                                                   347982
# comments_disabled                                                False
# ratings_disabled                                                 False
# description          There was an idea… Avengers: Infinity War. In ...
# Name: 16776, dtype: object

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# * Comment above the cells, showing what each codeblock is doing

# %% [markdown]
# -  ### Subtask 2.1:
#
# #### write here what the following codeblock is doing ( 1 mark )

# %%
videos.isnull().sum()

#The above code shows number of blank fields in each column in the dataset , we can clearly see that description has 516 Blank fields
# Out:
# video_id               0
# trending_date          0
# title                  0
# channel_title          0
# category_id            0
# tags                   0
# views                  0
# likes                  0
# dislikes               0
# comment_count          0
# comments_disabled      0
# ratings_disabled       0
# description          516
# dtype: int64

# %%
round(100*(videos.isnull().sum()/len(videos.index)), 2)

#The above code gives the %(percentage) of fields that are blank in each column.The detailed description is below :

#videos.isnull().sum() = gives the number of Blank or Null rows in each column
#len(videos.index) = given number of rows in each column = 32499
#round(x,2) = Gives the number rounded off to 2 decimal places
# Out:
# video_id             0.00
# trending_date        0.00
# title                0.00
# channel_title        0.00
# category_id          0.00
# tags                 0.00
# views                0.00
# likes                0.00
# dislikes             0.00
# comment_count        0.00
# comments_disabled    0.00
# ratings_disabled     0.00
# description          1.59
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.2:
#
# #### write here what the following codeblock is doing ( 1 mark )

# %%
videos = videos.drop(['trending_date','video_id','description'],  axis = 1)
videos

#The above code has given a dataframe which has 
#dropped/deleted the columns - video_id , trending_date and description from the dateframe .
#Also we can see the shape of the DF in the end says 10 column instead of 13
# Out:
#                                                    title    channel_title  \
# 0             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 1             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 2                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 3                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 4                        INDIA vs HINDIA | 1 Kg Biriyani    1 Kg Biriyani
# ...                                                  ...              ...
# 32494  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32495  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32496  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32497  How to maximise your chance of cracking 3rd Ju...        Unacademy
# 32498  How to maximise your chance of cracking 3rd Ju...        Unacademy
#
#        category_id                                               tags  \
# ...

# %%
videos.drop_duplicates(subset = None, keep = 'first', inplace = True)
videos

#The above code has removed the duplicate rows from each columns from the dataset
#subset = None - all the columns are used to find the duplicate rows
#keep: 'first’, duplicate rows except the first one is deleted
#inplace: if True, the source DataFrame is changed
#Rows changed from 32499 to 28876 rows
# Out:
#                                                    title    channel_title  \
# 0             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 1             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 2                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 3                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 4                        INDIA vs HINDIA | 1 Kg Biriyani    1 Kg Biriyani
# ...                                                  ...              ...
# 32493  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32494  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32495  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32496  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32497  How to maximise your chance of cracking 3rd Ju...        Unacademy
#
#        category_id                                               tags  \
# ...

# %% [markdown]
# -  ### Subtask 2.3:
#
# #### Explain what is being done in the codeblock below and comment if this step could be avoided given our previous analysis (2 marks )

# %%
videos = videos[~np.isnan(videos['views'])]
videos = videos[~np.isnan(videos['comment_count'])]
videos = videos[~np.isnan(videos['likes'])]
videos = videos[~np.isnan(videos['dislikes'])]

videos

#The code checks if there are any 'NaN'/'Not a Number'/'Null' Test in the columns (views,comment_count,likes,dislikes) and 
# removes the row which has NaN from the columns also
#as we can see that we have '~' present then its a negate condition so it keeps all row values which are NOT 'NaN'.

#According to me this step can be avoided as we have checked in 2.1 (videos.isnull().sum()) and saw that there are no blank values in columns (views,comment_count,like,dislikes)
# Out:
#                                                    title    channel_title  \
# 0             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 1             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 2                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 3                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 4                        INDIA vs HINDIA | 1 Kg Biriyani    1 Kg Biriyani
# ...                                                  ...              ...
# 32493  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32494  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32495  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32496  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32497  How to maximise your chance of cracking 3rd Ju...        Unacademy
#
#        category_id                                               tags  \
# ...

# %% [markdown]
# -  ### Subtask 2.4:
#
# #### Explain what is being done in the codeblock below  (1 mark )

# %%
videos.drop_duplicates(subset=["title"], keep = 'first', inplace = True)
videos

#The above code has removed the duplicate rows from columns - 'title' from the dataframe
#subset = title - Column 'title' is used to find the duplicate rows
#keep: 'first’, duplicate rows except the first one is deleted
#inplace: if True, the source DataFrame is changed
#Rows changed from 28876 to 14318  rows
# Out:
#                                                    title    channel_title  \
# 0             10,000 YEARS INTO THE FUTURE IN 10 MINUTES  #Mind Warehouse
# 2                The startup | 1 Kg Biriyani | TVF Machi    1 Kg Biriyani
# 4                        INDIA vs HINDIA | 1 Kg Biriyani    1 Kg Biriyani
# 7                      Musically vs Meme | 1 Kg Biriyani    1 Kg Biriyani
# 10     Relationship Expectation vs Reality | 1 Kg Bir...    1 Kg Biriyani
# ...                                                  ...              ...
# 32491  Unacademy Knowledge Fight - Roman Saini vs Bis...        Unacademy
# 32492  Current Affairs Daily MCQs for 15 April 2018 -...        Unacademy
# 32493  (AIR 124 UPSC CSE 2017) Strategy to crack UPSC...        Unacademy
# 32495  Solving UPSC Prelims 2018 Mock Paper Live  - T...        Unacademy
# 32497  How to maximise your chance of cracking 3rd Ju...        Unacademy
#
#        category_id                                               tags  \
# ...

# %% [markdown]
# ## Task 3: Data Analysis

# %% [markdown]
# -  ### 3.1: Identify and display the 10 videos with maximum views. (1 mark)

# %%
# Write your code here
max_views = videos.sort_values(by="views",ascending=False) #Sorted the views column from the data set in descending order
max_views[0:10] #Printing the First ten
# Out:
#                                                    title  \
# 16769  Marvel Studios' Avengers: Infinity War Officia...
# 7415         Ed Sheeran - Perfect (Official Music Video)
# 25652                      VENOM - Official Trailer (HD)
# 10250  Sanju | Official Trailer | Ranbir Kapoor | Raj...
# 16796  Marvel Studios' Avengers: Infinity War - Offic...
# 10229  Sanju | Official Teaser | Ranbir Kapoor | Rajk...
# 25411  Aastha Gill - Buzz feat Badshah | Priyank Shar...
# 31176  Official Trailer: Hate Story IV | Urvashi Raut...
# 6416   Dhadak | Official Trailer | Janhvi & Ishaan | ...
# 6391   ‘Raazi’ Official Trailer | Alia Bhatt, Vicky K...
#
#                      channel_title  category_id  \
# 16769         Marvel Entertainment           24
# 7415                    Ed Sheeran           10
# 25652  Sony Pictures Entertainment           24
# 10250                 FoxStarHindi           24
# 16796         Marvel Entertainment           24
# ...

# %% [markdown]
# -  ### 3.2: Identify and display the top 10 most viewed videos with less than 100 dislikes. (2 marks)

# %%
max_views.loc[max_views.dislikes < 100][0:10] #Filtering the last dataset with maximum views to less than 100 likes and selecting top 10
# Write your code here
# Out:
#                                                    title        channel_title  \
# 2268   The Test Case | ALT Balaji | Nimrat Kaur | New...            ALTBalaji
# 32255  Sri Reddy gets emotional seeing mother's inter...           TV9 Telugu
# 32265  Pawan Kalyan at Film Chamber over comments on ...           TV9 Telugu
# 3352   Kalakalappu 2 | Teaser | Hiphop Thamizha| Jiiv...          Avni Groups
# 23558  Andheri Raat | Nawazuddin | Vijay | Monsoon Sh...       Saregama Music
# 3351   Kalakalappu 2 | Teaser 2K | Jiiva, Jai, Shiva,...          Avni Groups
# 30215  சற்று முன் சசிகலா - கணவர் நடராஜனின்   உடலைப் ப...  Thirty Seconds News
# 15784  ഭാവനക്ക് വിവാഹസമ്മാനമായി മഞ്ജു നല്‍കിയത് കണ്ട്...  Malayalam News Time
# 527    తల్లి పార్థివదేహం దగ్గర శ్రీదేవి కూతురు చేసిన ...         9Roses Media
# 19705  Sridevi Dressed up in her Favourite Red and Go...           NTV Telugu
#
#        category_id                                               tags  \
# ...

# %% [markdown]
# -  ### 3.3: Identify the channel with the highest number of trending videos (1 mark)

# %%
# Write your code here
highest_trending = (videos.groupby(["channel_title"])['channel_title'].count()) #Grouping each channel title with the count
highest_trending
channel = highest_trending.idxmax() #Getting the name of channel
value = str(highest_trending.max()) #Getting the total number

print("Channel Name is  "+channel+" with highest number of trending videos to be "+value) #Printing values
# Out:
# Channel Name is  Study IQ education with highest number of trending videos to be 172

# %% [markdown]
# -  ### 3.4: How many videos have the ratings AND comments disabled? (2 marks)

# %%
#videos.loc[(videos.comments_disabled='True')]

count_disabled = len(videos.loc[(videos.comments_disabled == True) & (videos.ratings_disabled == True)]) #Filtering the videos with disabled comments and rating and finding the length

print("Number of videos with no ratings and comments are  "+ str(count_disabled)) #Printing value
# Out:
# Number of videos with no ratings and comments are  201

# %% [markdown]
# - ### 3.5: Display the names of the top 5 categories based on total views, with minimum 10,000 comments on each video. (4 marks)
#  Please note: The breakup in terms of steps below is just to prompt you to think in a particular direction. The prompts given suggest one way of accomplishing the task. Please feel free to do it any other way as well.

# %%
# Write your code here to select top 5 category ids with minimum 10000 comments in each video (2 marks)

top5 = []
comments = videos.loc[videos.comment_count >= 10000] #Getting the list of comments>10000
total_views_for_each_category = comments.groupby(["category_id"])["views"].sum().reset_index() #Getting the category Id based on sum of views
finalList = total_views_for_each_category.sort_values (by = "views" , ascending=False) [0:5] #Sorting the list and selecting Top 5
top5 = finalList['category_id'].tolist() #Filling the list
top5
# Out:
# [24, 10, 1, 23, 17]

# %%
Categories=pd.read_csv("Categories.csv",index_col="id") #Reading the Categories dataset

# %%
    #create a function that takes in a list of ids and outputs a list of category names coresponding to those ids (2 marks)

    def id_to_name(id_list):
        for val in id_list: 
            catname=Categories.loc[val].tolist() #Getting the name of Category based on the values in the list and converting to list
            lst1.append(catname) #Appending to new list

        return lst1 #Returing the list

    ids = top5 #Assigning ids to top5 which was the output of previous analysis
    lst1=[] #Creating new list



    print(id_to_name(ids)) #Printing the list
# Out:
# [['Entertainment'], ['Music'], ['Film & Animation'], ['Comedy'], ['Sports']]

# %% [markdown]
# ## Task 4: Channel Analysis

# %% [markdown]
# - ### 4.1: Find the most popular channel:
#     - by the highest total likes (1 mark)
#     - by the highest total views (1 mark)

# %%
# Write your code here
highestlikes = videos.groupby(["channel_title"]).agg({'likes':'sum'}) #Grouping by Sum of likes on channel_title
channel = highestlikes.idxmax()[0] #Getting the Channel Name
value = str(highestlikes.max()[0]) #Getting value of sum of likes on that channel
print("Channel with highest like is "+channel+" with total likes "+value) #Printing Values
# Out:
# Channel with highest like is PewDiePie with total likes 9570058

# %%
# Write your code here
highestviews = videos.groupby(["channel_title"]).agg({'views':'sum'})#Grouping by Sum of views on channel_title

channel = highestviews.idxmax()[0] #Getting the Channel Name
value = str(highestviews.max()[0]) #Getting value of sum of views on that channel
print("Channel with highest total views is "+channel+" with total views "+value) #Printing Values
# Out:
# Channel with highest total views is T-Series with total views 266298803

# %% [markdown]
# - ### 4.2: For the two selected channels, check which one has a higher number of negative responses per positive response. To do this, follow these steps:
#     - First, create two new data frames for each channel and sort the rows by the number of views. (2 marks)
#     - In each data frame, create a new column containing the ratio of dislikes/likes. (2 marks)
#     - Finally, check the summary statistics of both these (new) columns. (2 marks)
#     - Compare these results and identify which channel publishes more controversial videos (higher dislikes/likes value). (2 marks)

# %%
#Create and sort channel 1

channel1DF = videos.loc[videos.channel_title == 'PewDiePie'] #Creating new dataset with channeltitle = PewDiePie from previous analysis
channel1DF = channel1DF.sort_values(by="views",ascending=False) #Sorting the Dataframe in descending order
channel1DF #Printing DataFrame
# Out:
#                                                    title channel_title  \
# 20614                                     CURB YOUR MEME     PewDiePie
# 20646                                        RIP LIL TAY     PewDiePie
# 20640                       Are we ready to get married?     PewDiePie
# 20617  How I Made My Millions! (and so can you) 💰💰💰 B...     PewDiePie
# 20603                               show bobs and vegana     PewDiePie
# 20610                    LOGAN PAUL RETURNS  📰 PEW NEWS📰     PewDiePie
# 20580                 Why I'm not in YouTube Rewind 2017     PewDiePie
# 20654            The Greatest Meme of all time... [LOSS]     PewDiePie
# 20650        15 YEAR OLD CRIES OVER NOT GETTING $231,000     PewDiePie
# 20652                   The Greatest Meme of all time...     PewDiePie
# 20618                                 YOU LAUGH, YOU DIE     PewDiePie
# 20633                           YOU LAUGH, YOU TERRIFIED     PewDiePie
# ...

# %%
#Create and sort channel 2
channel2DF = videos.loc[videos.channel_title == 'T-Series'] #Creating new dataset with channeltitle = PewDiePie from previous analysis
channel2DF = channel2DF.sort_values(by="views",ascending=False) #Sorting the Dataframe in descending order
channel2DF #Printing the Dataframe
# Out:
#                                                    title channel_title  \
# 31176  Official Trailer: Hate Story IV | Urvashi Raut...      T-Series
# 31190  Raid | Official Trailer | Ajay Devgn | Ileana ...      T-Series
# 31237  Baaghi 2: Ek Do Teen Song | Jacqueline Fernand...      T-Series
# 31196  Boond Boond | Hate Story IV | Urvashi Rautela ...      T-Series
# 31282  Official Video: Raat Kamaal Hai | Guru Randhaw...      T-Series
# ...                                                  ...           ...
# 31127  Bulbul: Short Film | Divya Khosla Kumar | Shiv...      T-Series
# 31133  Song Teaser: SunDowner | AVI J | Releasing On ...      T-Series
# 31203  Official Teaser: The Remix  | Amazon Prime Vid...      T-Series
# 31130  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
# 31129  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
#
#        category_id                                               tags  \
# ...

# %%
#Create 'Ratio' column for channel 1
channel1DF['Ratio'] = channel1DF.apply(lambda row: row.dislikes / row.likes, axis=1) #Adding a new column as 'Ratio' in first DataFrame with lambda function to get ratio of dislikes/likes
channel1DF
# Out:
#                                                    title channel_title  \
# 20614                                     CURB YOUR MEME     PewDiePie
# 20646                                        RIP LIL TAY     PewDiePie
# 20640                       Are we ready to get married?     PewDiePie
# 20617  How I Made My Millions! (and so can you) 💰💰💰 B...     PewDiePie
# 20603                               show bobs and vegana     PewDiePie
# 20610                    LOGAN PAUL RETURNS  📰 PEW NEWS📰     PewDiePie
# 20580                 Why I'm not in YouTube Rewind 2017     PewDiePie
# 20654            The Greatest Meme of all time... [LOSS]     PewDiePie
# 20650        15 YEAR OLD CRIES OVER NOT GETTING $231,000     PewDiePie
# 20652                   The Greatest Meme of all time...     PewDiePie
# 20618                                 YOU LAUGH, YOU DIE     PewDiePie
# 20633                           YOU LAUGH, YOU TERRIFIED     PewDiePie
# ...

# %%
#Create 'Ratio' column for channel 2
channel2DF['Ratio'] = channel2DF.apply(lambda row: row.dislikes / row.likes, axis=1) #Adding a new column as 'Ratio' in second DataFrame with lambda function to get ratio of dislikes/likes
channel2DF
# Out:
#                                                    title channel_title  \
# 31176  Official Trailer: Hate Story IV | Urvashi Raut...      T-Series
# 31190  Raid | Official Trailer | Ajay Devgn | Ileana ...      T-Series
# 31237  Baaghi 2: Ek Do Teen Song | Jacqueline Fernand...      T-Series
# 31196  Boond Boond | Hate Story IV | Urvashi Rautela ...      T-Series
# 31282  Official Video: Raat Kamaal Hai | Guru Randhaw...      T-Series
# ...                                                  ...           ...
# 31127  Bulbul: Short Film | Divya Khosla Kumar | Shiv...      T-Series
# 31133  Song Teaser: SunDowner | AVI J | Releasing On ...      T-Series
# 31203  Official Teaser: The Remix  | Amazon Prime Vid...      T-Series
# 31130  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
# 31129  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
#
#        category_id                                               tags  \
# ...

# %%
#Check summary statistics of both channel's ratios 

channel1DF.describe().round(2) #Getting Statistical Analysis of all numeric rows in Dataframe1 upto 2 decimal palces
# Out:
#        category_id       views      likes  dislikes  comment_count  Ratio
# count        40.00       40.00      40.00     40.00          40.00  40.00
# mean         22.22  2785261.25  239251.45   4850.80       27871.05   0.02
# std           4.43  1039375.21   80530.52   2635.37       12485.10   0.01
# min           1.00   767932.00   81567.00   1637.00        6820.00   0.01
# 25%          23.00  2151418.50  170734.00   3004.25       19052.00   0.01
# 50%          23.50  2522929.50  229896.50   4394.50       24908.00   0.02
# 75%          24.00  3420511.00  288943.25   6143.25       40478.00   0.02
# max          27.00  5538066.00  420222.00  11429.00       52168.00   0.05

# %%
channel2DF.describe().round(2) #Getting Statistical Analysis of all numeric rows in Dataframe2 upto 2 decimal palces
# Out:
#        category_id        views      likes  dislikes  comment_count  Ratio
# count         66.0        66.00      66.00     66.00          66.00  66.00
# mean          10.0   4034830.35   81611.36   5062.73        5553.36   0.07
# std            0.0   4480083.68   84477.42   6944.12        6807.12   0.06
# min           10.0     57483.00    1084.00     95.00         145.00   0.01
# 25%           10.0    245176.25    7445.25    480.25         607.25   0.04
# 50%           10.0   2267373.00   51629.50   1886.50        2614.00   0.06
# 75%           10.0   6351392.25  134474.00   6956.50        9469.00   0.10
# max           10.0  16482187.00  299588.00  38691.00       34528.00   0.34

# %% [markdown]
# ## Which channel is more controversial? Justify your answer as a comment
#
# T-Series proves to be a more controvertial channel as the mean of Ratio(dislikes/likes) of T-Series is 0.07 whereas for PewDiePie is 0.02
